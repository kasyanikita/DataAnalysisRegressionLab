# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# %%
raw_path = os.path.join(os.path.dirname(os.path.abspath('')), "data/raw")
ds = pd.read_csv(os.path.join(raw_path, "train.csv"))

# %%
ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
ds.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_data = pd.read_pickle( "../data/interim/train_data.pkl")
train_target = pd.read_pickle( "../data/interim/train_target.pkl")
val_data = pd.read_pickle( "../data/interim/val_data.pkl")
val_target = pd.read_pickle( "../data/interim/val_target.pkl")

# %%
train_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 255           20       RL         70.0     8400   Pave      Reg         Lvl
# 1067          60       RL         59.0     7837   Pave      IR1         Lvl
# 639           30       RL         67.0     8777   Pave      Reg         Lvl
# 800           50       RL         60.0     7200   Pave      Reg         Lvl
# 381           50       RL         50.0     5000   Pave      Reg         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1096          20       RL         78.0     9317   Pave      IR1         Lvl
# 1131          50       RL         65.0     7804   Pave      Reg         Lvl
# 1295          20       RL         60.0     8172   Pave      Reg         Lvl
# 861           50       RL         55.0     7642   Pave      Reg         Lvl
# 1127         120       RL         53.0     3684   Pave      Reg         Lvl
#
# ...

# %%
train_target
# Out:
# Id
# 255     145000
# 1067    178000
# 639      85000
# 800     175000
# 381     127000
#          ...
# 1096    176432
# 1131    135000
# 1295    115000
# 861     189950
# 1127    174000
# Name: SalePrice, Length: 1168, dtype: int64

# %%
val_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 893           20       RL         70.0     8414   Pave      Reg         Lvl
# 1106          60       RL         98.0    12256   Pave      IR1         Lvl
# 414           30       RM         56.0     8960   Pave      Reg         Lvl
# 523           50       RM         50.0     5000   Pave      Reg         Lvl
# 1037          20       RL         89.0    12898   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 480           30       RM         50.0     5925   Pave      Reg         Bnk
# 1362          20       RL        124.0    16158   Pave      IR1         Low
# 803           60       RL         63.0     8199   Pave      Reg         Lvl
# 652           70       RL         60.0     9084   Pave      Reg         Lvl
# 723           20       RL         70.0     8120   Pave      Reg         Lvl
#
# ...

# %%
val_target
# Out:
# Id
# 893     154500
# 1106    325000
# 414     115000
# 523     159000
# 1037    315500
#          ...
# 480      89471
# 1362    260000
# 803     189000
# 652     108000
# 723     124500
# Name: SalePrice, Length: 292, dtype: int64

# %%
def is_garage(arr) -> list:
    ans = []
    for i in arr:
        if i:
            ans.append(1)
        else:
            ans.append(0)
    return ans

def add_garage_avail(df : pd.DataFrame) -> pd.DataFrame:
    df['GarageAvail'] = is_garage(df['GarageArea'])
    df['GarageAvail'] = df['GarageAvail'].astype(np.int8)
    return df

def add_garage_qual_ord(df : pd.DataFrame) -> pd.DataFrame:
    qualities = {'Po': 1, 'Fa': 2,'TA': 3, 'Gd': 4, 'Ex': 5}
    df['GarageQualOrd'] = df['GarageQual'].astype('string').map(qualities)
    df['GarageQualOrd'] = df['GarageQualOrd'].fillna(value=0)
    df['GarageQualOrd'] =  df['GarageQualOrd'].astype(np.int8)
    return df

def add_util_ord(df : pd.DataFrame) -> pd.DataFrame:
    utilities = {'ELO': 1, 'NoSeWa': 2, 'NoSewr': 3,'AllPub': 4}
    df['UtilsOrd'] = df['Utilities'].astype('string').map(utilities) 
    return df

# %%
train_data = add_garage_avail(train_data)
train_data = add_garage_qual_ord(train_data)
train_data = add_util_ord(train_data)
train_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 255           20       RL         70.0     8400   Pave      Reg         Lvl
# 1067          60       RL         59.0     7837   Pave      IR1         Lvl
# 639           30       RL         67.0     8777   Pave      Reg         Lvl
# 800           50       RL         60.0     7200   Pave      Reg         Lvl
# 381           50       RL         50.0     5000   Pave      Reg         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1096          20       RL         78.0     9317   Pave      IR1         Lvl
# 1131          50       RL         65.0     7804   Pave      Reg         Lvl
# 1295          20       RL         60.0     8172   Pave      Reg         Lvl
# 861           50       RL         55.0     7642   Pave      Reg         Lvl
# 1127         120       RL         53.0     3684   Pave      Reg         Lvl
#
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 255 to 1127
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   string
#  2   LotFrontage    951 non-null    float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   string
#  5   LotShape       1168 non-null   string
#  6   LandContour    1168 non-null   string
#  7   Utilities      1168 non-null   string
#  8   LotConfig      1168 non-null   string
#  9   LandSlope      1168 non-null   string
#  10  Neighborhood   1168 non-null   string
#  11  Condition1     1168 non-null   string
#  12  Condition2     1168 non-null   string
#  13  BldgType       1168 non-null   string
#  14  HouseStyle     1168 non-null   string
#  15  OverallQual    1168 non-null   int64
#  16  OverallCond    1168 non-null   int64
# ...

# %%
train_data = pd.read_pickle( "../data/processed/train_data.pkl")
val_data = pd.read_pickle( "../data/processed/val_data.pkl")

# %%
train_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 255           20       RL         70.0     8400   Pave      Reg         Lvl
# 1067          60       RL         59.0     7837   Pave      IR1         Lvl
# 639           30       RL         67.0     8777   Pave      Reg         Lvl
# 800           50       RL         60.0     7200   Pave      Reg         Lvl
# 381           50       RL         50.0     5000   Pave      Reg         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1096          20       RL         78.0     9317   Pave      IR1         Lvl
# 1131          50       RL         65.0     7804   Pave      Reg         Lvl
# 1295          20       RL         60.0     8172   Pave      Reg         Lvl
# 861           50       RL         55.0     7642   Pave      Reg         Lvl
# 1127         120       RL         53.0     3684   Pave      Reg         Lvl
#
# ...

# %%
train_data['FireplaceQu']
# Out:
# Id
# 255
# 1067    TA
# 639
# 800     TA
# 381     Gd
#         ..
# 1096    Gd
# 1131    TA
# 1295
# 861     Gd
# 1127    TA
# Name: FireplaceQu, Length: 1168, dtype: string

# %%
val_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 893           20       RL         70.0     8414   Pave      Reg         Lvl
# 1106          60       RL         98.0    12256   Pave      IR1         Lvl
# 414           30       RM         56.0     8960   Pave      Reg         Lvl
# 523           50       RM         50.0     5000   Pave      Reg         Lvl
# 1037          20       RL         89.0    12898   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 480           30       RM         50.0     5925   Pave      Reg         Bnk
# 1362          20       RL        124.0    16158   Pave      IR1         Low
# 803           60       RL         63.0     8199   Pave      Reg         Lvl
# 652           70       RL         60.0     9084   Pave      Reg         Lvl
# 723           20       RL         70.0     8120   Pave      Reg         Lvl
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
import category_encoders as ce
import src.config as cfg
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from catboost import CatBoostRegressor
from sklearn.ensemble import StackingRegressor

real_pipe = Pipeline([
    ('imputer', SimpleImputer()),
    ('scaler', StandardScaler())
    ]
)

cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='NA')),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse=False))
    ]
)

preprocess_pipe = ColumnTransformer(transformers=[
    ('real_cols', real_pipe, cfg.REAL_COLS),
    ('cat_cols', cat_pipe, cfg.CAT_COLS),
    # ('woe_cat_cols', ce.WOEEncoder(), cfg.CAT_COLS),
    ('ohe_cols', 'passthrough', cfg.NEW_OHE)
    ]
)

base_model = LinearRegression()

model = Pipeline([
    ('preprocess', preprocess_pipe),
    ('model', base_model)
    ]
)

catboost = CatBoostRegressor(iterations=50, cat_features=cfg.CAT_COLS, random_seed=cfg.RS)

estimators = [('lr', model), ('cat', catboost)]

stack_model = StackingRegressor(estimators, final_estimator=RandomForestRegressor(n_estimators=10, random_state=42))

# %%
import category_encoders as ce
from sklearn.utils.fixes import sklearn
import src.config as cfg
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from catboost import CatBoostRegressor
from sklearn.ensemble import StackingRegressor, RandomForestRegressor

real_pipe = Pipeline([
    ('imputer', SimpleImputer()),
    ('scaler', StandardScaler())
    ]
)

cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='NA')),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse=False))
    ]
)

preprocess_pipe = ColumnTransformer(transformers=[
    ('real_cols', real_pipe, cfg.REAL_COLS),
    ('cat_cols', cat_pipe, cfg.CAT_COLS),
    # ('woe_cat_cols', ce.WOEEncoder(), cfg.CAT_COLS),
    ('ohe_cols', 'passthrough', cfg.NEW_OHE)
    ]
)

base_model = LinearRegression()

sklearn_model = Pipeline([
    ('preprocess', preprocess_pipe),
    ('model', base_model)
    ]
)

catboost = CatBoostRegressor(iterations=50, cat_features=cfg.CAT_COLS, random_seed=cfg.RS)

estimators = [('lr', sklearn_model ), ('cat', catboost)]

stack = StackingRegressor(estimators, final_estimator=RandomForestRegressor(n_estimators=10, random_state=42))

# %%
stack.fit(train_data, train_target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [237], line 1
# ----> 1 stack.fit(train_data, train_target)
#
# File ~/DataAnalysisRegressionLab/env/lib/python3.8/site-packages/sklearn/ensemble/_stacking.py:866, in StackingRegressor.fit(self, X, y, sample_weight)
#     844 """Fit the estimators.
#     845
#     846 Parameters
#    (...)
#     863     Returns a fitted instance.
#     864 """
#     865 y = column_or_1d(y, warn=True)
# --> 866 return super().fit(X, y, sample_weight)
#
# File ~/DataAnalysisRegressionLab/env/lib/python3.8/site-packages/sklearn/ensemble/_stacking.py:189, in _BaseStacking.fit(self, X, y, sample_weight)
#     184             self.estimators_.append(estimator)
#     185 else:
#     186     # Fit the base estimators on the whole training data. Those
#     187     # base estimators will be used in transform, predict, and
# ...

# %%
stack_model.fit(train_data, train_target)
# Out:
# /home/ebuzanov/DataAnalysisRegressionLab/env/lib/python3.8/site-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# Learning rate set to 0.479262
# 0:	learn: 57504.0641530	total: 86.6ms	remaining: 4.24s
# 1:	learn: 45457.5174206	total: 143ms	remaining: 3.42s
# 2:	learn: 38065.7351788	total: 227ms	remaining: 3.56s
# 3:	learn: 33885.2558347	total: 322ms	remaining: 3.7s
# 4:	learn: 30717.3389593	total: 367ms	remaining: 3.3s
# 5:	learn: 28796.6798951	total: 452ms	remaining: 3.31s
# 6:	learn: 27967.5014180	total: 518ms	remaining: 3.18s
# 7:	learn: 26847.5684819	total: 555ms	remaining: 2.91s
# 8:	learn: 25971.0257211	total: 604ms	remaining: 2.75s
# 9:	learn: 25123.2493857	total: 637ms	remaining: 2.55s
# 10:	learn: 24480.7384103	total: 731ms	remaining: 2.59s
# ...

# %%
stack_model.score(val_data, val_target)
# Out:
# /home/ebuzanov/DataAnalysisRegressionLab/env/lib/python3.8/site-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# 0.8505338982674948
